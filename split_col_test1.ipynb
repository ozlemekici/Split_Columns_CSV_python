# %%
import pandas as pd
import numpy as np
df = pd.read_csv("att-start-1.csv")
df
# Out:
#               sku                                            alchool  \
# 0         ILFOLLO  animal=1,bottleml=750,box_size=12,cellar_pract...
# 1    SMANGRUJ05-1  alchool=10,alt_image=/a/n/anghelo_rujo_edited-...
# 2      OLBCANGR15  alchool=10,alt_image=/c/a/cangrande_test.jpg,a...
# 3        ZAMFIA19  alchool=10,alt_image=/p/i/pierluigi_zampaglion...
# 4        VINMUL18  alchool=10,alt_image=/r/u/rudi_vindimian_mulle...
# ..            ...                                                ...
# 379       MAZCH20  alt_image=/t/e/tenuta_mazzolino_blanc_mazch19_...
# 380      PEDNOS20  area=Valle dei Laghi,bottleml=750,box_size=12,...
# 381      LEDSRO18  alt_image=/l/e/le_due_terre_sacrisassi_rosso_l...
# 382     FSLOCHE20  area=Castelli di Jesi,bottleml=700,box_size=12...
# 383       PGMOS21  alt_image=/p/i/piero_gatti_moscato_pgmos19_1_1...
#
#      alt_image  animal  area  australian_like  awards  blended_grapes  \
# ...

# %%
for i in range(df.shape[0]):
    #print(df.iloc[i])
    data = df.iloc[i][1]
    #print(i,":",data)
    data_arr = data.split(",")
    #print(data_arr)
    for keyval in data_arr:
        #print(keyyval)
        if (keyval.find("=")<0):
            continue
        [key,val] = keyval.split("=")
        #print(key,val)
        df.loc[i,key] = val
    #print("--"*15)   

df
# Out:
#               sku                                            alchool  \
# 0         ILFOLLO  animal=1,bottleml=750,box_size=12,cellar_pract...
# 1    SMANGRUJ05-1                                                 10
# 2      OLBCANGR15                                                 10
# 3        ZAMFIA19                                                 10
# 4        VINMUL18                                                 10
# ..            ...                                                ...
# 379       MAZCH20  alt_image=/t/e/tenuta_mazzolino_blanc_mazch19_...
# 380      PEDNOS20  area=Valle dei Laghi,bottleml=750,box_size=12,...
# 381      LEDSRO18  alt_image=/l/e/le_due_terre_sacrisassi_rosso_l...
# 382     FSLOCHE20  area=Castelli di Jesi,bottleml=700,box_size=12...
# 383       PGMOS21  alt_image=/p/i/piero_gatti_moscato_pgmos19_1_1...
#
#                                              alt_image animal  \
# 0                                                  NaN      1
# ...

# %%
df.iloc[:,1].apply(len)>5
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 379     True
# 380     True
# 381     True
# 382     True
# 383     True
# Name: alchool, Length: 384, dtype: bool

# %%
df["alchool"].apply(len)>5
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 379     True
# 380     True
# 381     True
# 382     True
# 383     True
# Name: alchool, Length: 384, dtype: bool

# %%
df.iloc[0:5,:]
# Out:
#             sku                                            alchool  \
# 0       ILFOLLO  animal=1,bottleml=750,box_size=12,cellar_pract...
# 1  SMANGRUJ05-1                                                 10
# 2    OLBCANGR15                                                 10
# 3      ZAMFIA19                                                 10
# 4      VINMUL18                                                 10
#
#                                            alt_image animal         area  \
# 0                                                NaN      1          NaN
# 1            /a/n/anghelo_rujo_edited-pixlr_copy.jpg      2      Alghero
# 2                            /c/a/cangrande_test.jpg    NaN      Gallura
# 3  /p/i/pierluigi_zampaglione_fiano_don_chisciott...    NaN      Irpinia
# 4     /r/u/rudi_vindimian_muller_turgau_vinmul18.png    NaN  Vallagarina
#
#    australian_like  awards blended_grapes bottleml box_size  ... tastingnotes  \
# ...

# %%
df.to_csv("data_parsed2.csv") #save
